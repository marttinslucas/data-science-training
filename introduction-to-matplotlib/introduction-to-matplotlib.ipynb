# %% [raw]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11, 22, 33, 44]

# %%
plt.plot(x,y);

# %%
# 1st method

fig = plt.figure() # creates a figure

ax = fig.add_subplot() # adds axes

plt.show()

# %%
# 2nd method

fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) # add some data
plt.show()

# %%
# 3rd method (recommended)

fig, ax = plt.subplots()
ax.plot(x,y);

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter notebook!
# %matplotlib inline

import matplotlib.pyplot as plt

# 1. prepare some data

x = [1,2,3,4]
y = [11,22,33,44]

# 2. setup plot

fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data

ax.plot(x,y)

# 4. customize plot

ax.set(title="Simple plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save and show (you save the whole figure)

fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with numpy arrays

# %%
# Crete some data

x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
x.shape
# Out:
# (100,)

# %%
# Plot the data and create a line plot

fig, ax = plt.subplots()

ax.plot(x,x**2);

# %%
# Create a scatter plot
fig, ax = plt.subplots()

ax.scatter(x,np.exp(x));

# %%
# Another scatter plot

fig, ax = plt.subplots()

ax.scatter(x,np.sin(x));

# %%
# Make a plot from disctionary

# %%
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()

ax.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax.set(title="Price of butter types", xlabel="Butter types", ylabel="Price ($)");

# %%
# barh graph

fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %%
# make some data

x = np.random.randn(1000)

fig, ax = plt.subplots()

ax.hist(x);

# %%
# Subplot option 1

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10,10))
# plot data to each different axis

ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.hist(np.random.randn(200));
ax4.bar(np.linspace(200, 300, 1000),np.linspace(200, 300, 1000));

# %%
## Plotting pandas dataframes

car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
                index = pd.date_range("1/1/2021", periods = 1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\.\,]', '', regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].astype('int64')
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %%
car_sales["Price"] = car_sales["Price"]/100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales.shape[0]
# Out:
# 10

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2021", periods = car_sales.shape[0])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date
# 0  Toyota  White         150043      4   4000.0 2021-01-01
# 1   Honda    Red          87899      4   5000.0 2021-01-02
# 2  Toyota   Blue          32549      3   7000.0 2021-01-03
# 3     BMW  Black          11179      5  22000.0 2021-01-04
# 4  Nissan  White         213095      4   3500.0 2021-01-05
# 5  Toyota  Green          99213      4   4500.0 2021-01-06
# 6   Honda   Blue          45698      4   7500.0 2021-01-07
# 7   Honda   Blue          54738      4   7000.0 2021-01-08
# 8  Toyota  White          60000      4   6250.0 2021-01-09
# 9  Nissan  White          31600      4   9700.0 2021-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2021-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2021-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2021-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2021-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2021-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2021-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2021-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2021-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2021-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2021-01-10      76450.0

# %%
# Let's plot the total sales

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(car_sales["Sale Date"],car_sales["Total Sales"]);
ax.set(title="Sales graph", xlabel="Sales Date", ylabel="Price of sale");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
car_sales.shape
# Out:
# (10, 7)

# %%
# creating a bar graph

x = np.random.rand(10,4)
x
# Out:
# array([[0.34407433, 0.69008667, 0.15488992, 0.81162305],
#        [0.38342593, 0.19447026, 0.84841891, 0.87095688],
#        [0.73242723, 0.75996768, 0.06395616, 0.00296001],
#        [0.55172047, 0.84447392, 0.85250075, 0.07858778],
#        [0.85239963, 0.24495096, 0.59466988, 0.67012468],
#        [0.94146739, 0.64862179, 0.4860664 , 0.2739065 ],
#        [0.26745017, 0.70063824, 0.50797423, 0.20780537],
#        [0.29726716, 0.06411113, 0.74962335, 0.12035406],
#        [0.91456075, 0.93471546, 0.11143359, 0.2724786 ],
#        [0.46451212, 0.53555984, 0.01536154, 0.76788506]])

# %%
# turn it into a dataframe

df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.344074  0.690087  0.154890  0.811623
# 1  0.383426  0.194470  0.848419  0.870957
# 2  0.732427  0.759968  0.063956  0.002960
# 3  0.551720  0.844474  0.852501  0.078588
# 4  0.852400  0.244951  0.594670  0.670125
# 5  0.941467  0.648622  0.486066  0.273907
# 6  0.267450  0.700638  0.507974  0.207805
# 7  0.297267  0.064111  0.749623  0.120354
# 8  0.914561  0.934715  0.111434  0.272479
# 9  0.464512  0.535560  0.015362  0.767885

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2021-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2021-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2021-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2021-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2021-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2021-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2021-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2021-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2021-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2021-01-10      76450.0

# %%
car_sales.plot(x= "Make", y= "Odometer (KM)", kind="bar");

# %%
car_sales.nunique()
# Out:
# Make              4
# Colour            5
# Odometer (KM)    10
# Doors             3
# Price             9
# Sale Date        10
# Total Sales      10
# dtype: int64

# %%
np.unique(car_sales["Make"])
# Out:
# array(['BMW', 'Honda', 'Nissan', 'Toyota'], dtype=object)

# %%
# let's try in another dataset

heart_disease = pd.read_csv("heart-disease.csv")

# %%
heart_disease = pd.DataFrame(heart_disease)

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# create a histogram

heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.plot.hist(figsize=(15,15),subplots=True);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method
over_50.plot(kind="scatter", x="age", y="chol", c="target");

# %%
# recreating with OO method mixed with pyplot method

fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter", x="age", y="chol", c="target", ax=ax);
ax.set_xlim([45,100]);

# %%
## OO method from scratch

fig, ax = plt.subplots(figsize=(10,6))

## plot the data

scatter = ax.scatter(x = over_50["age"], y=over_50["chol"], c=over_50["target"])

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# add a legend 
ax.legend(*scatter.legend_elements(), title="Target")

# add horizontal line

ax.axhline(130, linestyle="--");

# %%
# subplot of chol , age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)
# add data to axes 0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"])
# customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels", ylabel="Cholesterol")
# add a legend
ax0.legend(*scatter.legend_elements(),title="Target");
# add a mean line
ax0.axhline(y=over_50["chol"].mean(), linestyle="--");

# add data to axes 1
scatter1 = ax1.scatter(x=over_50["age"],
                       y=over_50["thalach"],
                       c=over_50["target"])

# customize ax1
ax1.set(title="Heart Disease and Heart Frequency", xlabel="Age", ylabel="Heart Frequency");

# add a legend to ax1
ax1.legend(*scatter1.legend_elements(),title="Target");

# add a mean line to ax1

ax1.axhline(y=over_50["thalach"].mean(), linestyle="--");

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## Customize the graphs

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2021-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2021-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2021-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2021-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2021-01-05      41500.0

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x = "Odometer (KM)", y = "Price", kind="scatter");

# %%
# create some dummy data

x = np.random.randn(10,4)
x
# Out:
# array([[ 0.89316143, -2.09158488, -0.46559335, -0.31394249],
#        [ 1.72574366,  0.103198  , -0.53527289, -0.5526283 ],
#        [-0.01441414, -0.07879703,  1.44483341, -0.87698777],
#        [-0.80959441,  1.1658756 ,  0.24684991, -0.48987911],
#        [-1.22204106,  1.8520052 , -0.12172043,  1.45592299],
#        [ 0.86255284, -0.66790101,  0.58363567, -0.38287514],
#        [-0.44541666,  2.88458497, -1.25090793, -1.02961262],
#        [ 0.34554883, -0.29423626, -0.22180534, -0.55735726],
#        [ 0.58673561, -0.72441959,  0.03445716,  0.97973577],
#        [ 0.19827877, -0.10575682,  1.3394857 ,  0.55907274]])

# %%
# turn into a dataframe

df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.893161 -2.091585 -0.465593 -0.313942
# 1  1.725744  0.103198 -0.535273 -0.552628
# 2 -0.014414 -0.078797  1.444833 -0.876988
# 3 -0.809594  1.165876  0.246850 -0.489879
# 4 -1.222041  1.852005 -0.121720  1.455923
# 5  0.862553 -0.667901  0.583636 -0.382875
# 6 -0.445417  2.884585 -1.250908 -1.029613
# 7  0.345549 -0.294236 -0.221805 -0.557357
# 8  0.586736 -0.724420  0.034457  0.979736
# 9  0.198279 -0.105757  1.339486  0.559073

# %%
ax = df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# Customize our plot with the set() method

ax = df.plot(kind="bar")
# creating labels for the graph
ax.set(title="Random bar graph from dataframe", xlabel="Row number", ylabel="Random number")

# make the legend visible
ax.legend().set_visible(True)

# %%
# Set the style
plt.style.use('seaborn-whitegrid')

## OO method from scratch

fig, ax = plt.subplots(figsize=(10,6))

## plot the data

scatter = ax.scatter(x = over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# add a legend 
ax.legend(*scatter.legend_elements(), title="Target")

# add horizontal line

ax.axhline(heart_disease["chol"].mean(), linestyle="--");

# %%
# customize x and y limitations
plt.style.use('seaborn-whitegrid')

# subplot of chol , age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)

# add data to axes 0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"],
                      cmap="winter")
# customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# change the axis limits
ax0.set_xlim([50,80])

# add a legend
ax0.legend(*scatter.legend_elements(),title="Target");

# add a mean line
ax0.axhline(y=over_50["chol"].mean(), linestyle="--");

# add data to axes 1
scatter1 = ax1.scatter(x=over_50["age"],
                       y=over_50["thalach"],
                       c=over_50["target"],
                       cmap="winter")

# customize ax1
ax1.set(title="Heart Disease and Heart Frequency", 
        xlabel="Age", 
        ylabel="Heart Frequency");
# change ax1 x axis limits
ax1.set_ylim([60,200])
# add a legend to ax1
ax1.legend(*scatter1.legend_elements(),title="Target");

# add a mean line to ax1

ax1.axhline(y=over_50["thalach"].mean(), linestyle="--");

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
fig.savefig("heart-disease-analysis-plot-saved-w-code.png")
